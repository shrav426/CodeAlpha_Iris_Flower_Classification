# %% [markdown]
# <a href="https://colab.research.google.com/github/shrav426/CodeAlpha_Iris_Flower_Classification/blob/main/crs_projectipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("======================================================")
print("        SMART CAREER RECOMMENDATION SYSTEM")
print("======================================================\n")

# ============================================================
# USER DETAILS
# ============================================================

name = input("Enter Your Name : ")
age = input("Enter Your Age : ")

print("\nGive Ratings Between 1 to 10")
print("1 = Low Interest")
print("10 = High Interest\n")

# ============================================================
# USER INPUTS
# ============================================================

coding = int(input("Coding Skills : "))
maths = int(input("Math Skills : "))
communication = int(input("Communication Skills : "))
leadership = int(input("Leadership Skills : "))
business = int(input("Business Interest : "))
finance = int(input("Finance Interest : "))
technology = int(input("Technology Interest : "))
government = int(input("Government Job Interest : "))
management = int(input("Management Skills : "))
problem_solving = int(input("Problem Solving Skills : "))
research = int(input("Research Interest : "))
gaming = int(input("Gaming Interest : "))
photography = int(input("Photography Interest : "))
robotics = int(input("Robotics Interest : "))

# CAREER RECOMMENDATION LOGIC


career = ""
course = ""
reason = ""

# 1
if coding >= 8 and maths >= 8 and technology >= 8:
    career = "Data Scientist / AI Engineer"
    course = "B.Tech AI, BCA + MCA Data Science"
    reason = "Excellent coding and analytical skills."

# 2
elif maths >= 7 and communication >= 7 and technology >= 6:
    career = "Data Analyst"
    course = "BSc Data Analytics, BCA"
    reason = "Good at data handling and analysis."

# 3
elif coding >= 8 and maths >= 8 and problem_solving >= 8:
    career = "Machine Learning Engineer"
    course = "B.Tech AI/ML"
    reason = "Strong coding and logical thinking."

# 4
elif coding >= 7 and technology >= 8:
    career = "Cloud Engineer"
    course = "Cloud Computing, AWS"
    reason = "Interest in cloud technologies."

# 5
elif coding >= 7 and technology >= 7:
    career = "Software Developer"
    course = "B.Tech, BCA, MCA"
    reason = "Good programming and technical skills."

# 6
elif coding >= 7 and problem_solving >= 8:
    career = "Cyber Security Analyst"
    course = "Cyber Security Courses"
    reason = "Strong logical and security mindset."

# 7
elif research >= 8 and coding >= 7:
    career = "AI Researcher"
    course = "M.Tech AI, Research Programs"
    reason = "Interest in research and artificial intelligence."

# 8
elif coding >= 7 and finance >= 7:
    career = "Blockchain Developer"
    course = "Blockchain Development"
    reason = "Interest in coding and finance technology."

# 9
elif leadership >= 8 and management >= 8:
    career = "MBA Professional / Business Manager"
    course = "BBA + MBA"
    reason = "Strong leadership and management skills."

# 10
elif finance >= 8 and maths >= 7:
    career = "Financial Analyst / CA / Banker"
    course = "B.Com, MBA Finance, CA"
    reason = "Strong finance and calculation skills."

# 11
elif business >= 7 and communication >= 7:
    career = "Business Analyst"
    course = "BBA, MBA Business Analytics"
    reason = "Good business analysis skills."

# 12
elif communication >= 8 and business >= 7:
    career = "Digital Marketer"
    course = "MBA Marketing"
    reason = "Strong communication and marketing skills."

# 13
elif business >= 8 and leadership >= 7:
    career = "Entrepreneur / Startup Founder"
    course = "BBA Entrepreneurship"
    reason = "Business mindset and leadership quality."

# 14
elif government >= 8:
    career = "Government Officer / UPSC Aspirant"
    course = "Any Graduation"
    reason = "Strong interest in government services."

# 15
elif robotics >= 8:
    career = "Robotics Engineer"
    course = "B.Tech Robotics"
    reason = "Interest in robotics and automation."

# 16
elif gaming >= 8:
    career = "Game Developer / Streamer"
    course = "Game Development"
    reason = "Interest in gaming and creativity."

# 17
elif photography >= 8:
    career = "Photographer / Cinematographer"
    course = "Photography Courses"
    reason = "Visual creativity skills."

# DEFAULT
else:
    career = "Multitalented Student"
    course = "Explore Different Career Fields"
    reason = "Balanced skills in multiple areas."


# DATAFRAME


skills = {
    "Skills": [
        "Coding",
        "Maths",
        "Communication",
        "Leadership",
        "Business",
        "Finance",
        "Technology",
        "Government",
        "Management",
        "Problem Solving",
        "Research",
        "Gaming",
        "Photography",
        "Robotics"
    ],

    "Scores": [
        coding,
        maths,
        communication,
        leadership,
        business,
        finance,
        technology,
        government,
        management,
        problem_solving,
        research,
        gaming,
        photography,
        robotics
    ]
}

df = pd.DataFrame(skills)


# FINAL OUTPUT


print("\n======================================================")
print("                 STUDENT REPORT")
print("======================================================\n")

print("Student Name :", name)
print("Age          :", age)

print("\n======================================================")
print("                  SKILL ANALYSIS")
print("======================================================\n")

print(df)

print("\n======================================================")
print("             CAREER RECOMMENDATION")
print("======================================================\n")

print("Recommended Career : ", career)

print("\nSuggested Course : ", course)

print("\nReason : ")
print(reason)

print("\n======================================================")
print("                 PROJECT COMPLETED")
print("======================================================\n")

print("Thank You,", name)
print("This project is made using Python and Data Science.")
# Out:
# ...
#         SMART CAREER RECOMMENDATION SYSTEM
# ...
